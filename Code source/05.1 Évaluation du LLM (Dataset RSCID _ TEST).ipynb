# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path_csv = "/content/drive/MyDrive/Classroom/MSV/predictions.csv"
path_json = "/content/drive/MyDrive/Classroom/MSV/dataset RSICD/dataset_rsicd.json"
path_img_folder = "/content/drive/MyDrive/Classroom/MSV/dataset RSICD/images"

import json

# Charger le fichier JSON
with open(path_json, 'r') as file:
    data = json.load(file)

# Création du dataset
dataset_map = {}
for item in data["images"]:
    filename = item['filename']
    captions = [sent['raw'] for sent in item['sentences']]
    dataset_map[filename] = captions

# %%
import pandas as pd
import re

# Charger le fichier CSV
df = pd.read_csv(path_csv)

# Fonction pour extraire le texte après "### Response:"
def extract_response(text):
    match = re.search(r'### Response:(.*)', text, re.DOTALL)
    if match:
        return match.group(1).strip()
    return ''

# Appliquer la fonction à la colonne 'pred_output'
df['pred_output'] = df['pred_output'].apply(extract_response)

# Sauvegarder les modifications dans un nouveau fichier CSV
df.to_csv("/content/drive/MyDrive/Classroom/MSV/predictions_2.csv", index=False)

# %%
df = pd.read_csv("/content/drive/MyDrive/Classroom/MSV/predictions_2.csv")

hypothesis = {f"ref_{i+1}": [row['pred_output']] for i, row in df.iterrows()}
references = {f"ref_{i+1}": dataset_map[row['filename']][:5] for i, row in df.iterrows()}

# Afficher les dictionnaires
print("Hypothesis:", hypothesis)
print(len(hypothesis))
print("References:", references)
print(len(references))
# Out:
# Hypothesis: {'ref_1': ['many green trees are around a piece of land .'], 'ref_2': ['a road is next to a railway station and a parking lot .'], 'ref_3': ['a pond is surrounded by a green meadow .'], 'ref_4': ['some green trees and buildings are in a piece of land .'], 'ref_5': ['a road is between two buildings and two parking lots .'], 'ref_6': ['some buildings and green trees are in a dense residential area .'], 'ref_7': ['a large parking lot is near a residential area .'], 'ref_8': ['many buildings and green trees are in a densely populated residential area .'], 'ref_9': ['many green trees are in a piece of meadow .'], 'ref_10': ['a green meadow is near a piece of water .'], 'ref_11': ['a green field with a few buildings are in a residential area .'], 'ref_12': ['the road is in a dense residential area with many buildings and green trees .'], 'ref_13': ['the red roofs of many buildings are scattered in a densely populated area .'], 'ref_14': ['the white building is surrounded by many green trees .'], 'ref_15': ['a big building is in a piece of green land .'], 'ref_16': ['a large piece of green land is surrounded by a few buildings .'], 'ref_17': ['some buildings are near a green area .'], 'ref_18': ['a white building with a red roof is surrounded by green trees .'], 'ref_19': ['some buildings and green trees are in a piece of farmland .'], 'ref_20': ['the road with many cars is in the center of a roundabout .'], 'ref_21': ['the road is next to a piece of green land .'], 'ref_22': ['a big green field with a few buildings and a playground .'], 'ref_23': ['a white building is near a pond .'], 'ref_24': ['a green meadow is surrounded by many buildings and some trees .'], 'ref_25': ['a piece of green meadow is near a river .'], 'ref_26': ['a few cars are parked in front of a school .'], 'ref_27': ['the parking lot is surrounded by buildings .'], 'ref_28': ['a green meadow is near a piece of green forest .'], 'ref_29': ['the playground is surrounded by buildings .'], 'ref_30': ['there are many green trees and a few buildings in a piece of farmland .'], 'ref_31': ['some green trees are in a piece of farmland .'], 'ref_32': ['some green trees and buildings are in a piece of green meadow .'], 'ref_33': ['the buildings are in the residential area .'], 'ref_34': ['a white car is parked in a large parking lot .'], 'ref_35': ['the white building is in the center of a square .'], 'ref_36': ['many buildings are in a commercial area with many green trees and a river .'], 'ref_37': ['a small river is flowing through a green meadow .'], 'ref_38': ['there are many green trees in a piece of farmland .'], 'ref_39': ['the road is in a green field .'], 'ref_40': ['there is a big playground with many children in it .'], 'ref_41': ['a large piece of green meadow is surrounded by a dense pine forest .'], 'ref_42': ['the road is full of cars and the bridge is built on the river .'], 'ref_43': ['a playground is near a residential area .'], 'ref_44': ['the parking lot is surrounded by several buildings .'], 'ref_45': ['there are some buildings and green trees in a piece of piece of meadow .'], 'ref_46': ['there are a lot of green trees in a piece of land .'], 'ref_47': ['a road is in a piece of green meadow .'], 'ref_48': ['many buildings are in a piece of green park .'], 'ref_49': ['the parking lot is in a dense residential area .'], 'ref_50': ['many green trees are near a river .'], 'ref_51': ['a red roofed house with two chimneys is in a piece of green meadow .'], 'ref_52': ['a large number of buildings are in a residential area .'], 'ref_53': ['the green meadows are surrounded by buildings and the trees are in the farmland .'], 'ref_54': ['some buildings are in a piece of green meadows .'], 'ref_55': ['many green trees are in a piece of dense forest .'], 'ref_56': ['a piece of green meadow is in a mountain .'], 'ref_57': ['a large pond with green trees and some buildings are near it .'], 'ref_58': ['many buildings are in a commercial area .'], 'ref_5 ...
# 1092
# References: {'ref_1': ['villas, tennis courts, parking lots and lush plants make up this amazing space .', 'a badminton field and a parking lot not far away from it .', 'a building and some green trees are around four tennis courts .', 'four tennis courts are semisurrounded by many green trees and a large building .', 'four tennis courts are surrounded by many green trees .'], 'ref_2': ['the community owns a baseball field, a swimming pool,some tennis courts and basketball courts .', 'a badminton field with four big trees beside .', 'two tennis courts are near a baseball field and a basketball field .', 'a baseball field is next to two tennis courts .', 'two tennis courts and a basketball field are next to a baseball field .'], 'ref_3': ['the magnificent football field is located behind that white, noticeable building .', 'an outdoor gymnasium and many buildings surrounded .', 'many buildings are around a playground with a football field in it .', 'a playground is semisurrounded by many buildings .', 'a playground with a football field in it is surrounded by many buildings .'], 'ref_4': ['the huge rectangle contains a baseball field, a swimming pool, two basketball courts and eight tennis courts, surrounded by corwded cars .', 'a square court and many blue buildings on the north .', 'eight tennis courts and a baseball field are near three parking lots .', 'a baseball field is next to eight tennis courts .', 'a baseball field and eight tennis courts are next to a parking lot .'], 'ref_5': ["the football field marked with 'bison' sits between distinctive buildings and a lake .", 'a big court and a curving road beside .', 'several buildings and a road are around a playground with a football field in it .', 'a playground is between a road and several large buildings .', 'a playground with a football field in it is between a road and several buildings .'], 'ref_6': ['six tennis courts is lacated near the villa and is surrounded by paths .', 'three badminton fields and many trees in the east .', 'several trees and two buildings are around six tennis courts .', 'six tennis courts are surrounded by several buildings and trees .', 'six tennis courts are next to two buildings .'], 'ref_7': ['in the area formed by two intersecting roads, two tennis courts and two basketball courts can be seen .', 'two basketball courts and two badminton fields in the west .', 'two basketball fields and two tennis courts are near a crossroads .', 'two basketball fields and two tennis courts are next to a crossroads .', 'two basketball fields and two tennis courts are next to a crossroads .'], 'ref_8': ['the huge irregular grassland includes a tennis court, two tennis courts and an orange pavilion .', 'a small badminton field and two little big basketball courts in the east .', 'two basketball fields and a tennis court are surrounded by several crossed roads .', 'two basketball fields are next to a tennis court .', 'two basketball fields are next to a tennis court .'], 'ref_9': ['the standard basketball courts is situated near the street .', 'a football field and a broad road surrounded .', 'some buildings and a basketball field are in two sides of a road .', 'a road is between a basketball field and several buildings .', 'a basketball field and several buildings are in two sides of a road .'], 'ref_10': ['what stand beside a row of houses include a tennis court, a basketball court and a attractive white building .', 'a green basketball court and a small rectangular badminton field .', 'a basketball field and a tennis court are near some buildings .', 'a basketball field and a tennis court are surrounded by several buildings .', 'a basketball field and a tennis court are next to many buildings .'], 'ref_11': ['two tennis courts, a baseball field and a parking lot are in the open space between crowded buildings .', 'a irregular court and a parking lot beside .', 'a baseball field and two tennis courts are between two pieces of buildings .', 'a baseball fiel ...
# 1092

# %%
# !pip install tabulate
# !pip install pycocoevalcap
# Out:
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (0.9.0)
# Collecting pycocoevalcap
#   Downloading pycocoevalcap-1.2-py3-none-any.whl (104.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.3/104.3 MB 9.0 MB/s eta 0:00:00
# Requirement already satisfied: pycocotools>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from pycocoevalcap) (2.0.7)
# Requirement already satisfied: matplotlib>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from pycocotools>=2.0.2->pycocoevalcap) (3.7.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from pycocotools>=2.0.2->pycocoevalcap) (1.25.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap) (24.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap) (1.16.0)
# Installing collected packages: pycocoevalcap
# Successfully installed pycocoevalcap-1.2

# %%
import pandas as pd
import re
from pycocoevalcap.bleu.bleu import Bleu
from pycocoevalcap.rouge.rouge import Rouge
from pycocoevalcap.cider.cider import Cider
from pycocoevalcap.meteor.meteor import Meteor
from tabulate import tabulate

def show_metrics(metrics):
    table_data = []
    for metric, value in metrics.items():
        table_data.append([metric, value])
    headers = ['Metric', 'Value']
    print(tabulate(table_data, headers=headers, tablefmt='fancy_grid'))

class MetricsCalculator:
    def __init__(self, references, hypotheses, n_gram=4):
        self.references = references
        self.hypotheses = hypotheses
        self.n_gram = n_gram
        self.bleu = Bleu(self.n_gram)
        self.rouge = Rouge()
        self.cider = Cider()
        self.meteor = Meteor()
        self.scores = {}

    def compute_bleu(self):
        bleu_scores = self.bleu.compute_score(self.references, self.hypotheses)
        for i in range(self.n_gram):
            self.scores[f"BLEU-{i+1}"] = f"{bleu_scores[0][i] * 100:.2f}"  # Convert to percentage

    def compute_rouge_l(self):
        rouge_scores, _ = self.rouge.compute_score(self.references, self.hypotheses)
        self.scores["ROUGE-L"] = f"{rouge_scores * 100:.2f}"

    def compute_cider(self):
        scores, _ = self.cider.compute_score(self.references, self.hypotheses)
        self.scores["CIDEr"] = scores

    def compute_meteor(self):
        scores, _ = self.meteor.compute_score(self.references, self.hypotheses)
        self.scores["METEOR"] = f"{scores * 100:.2f}"

# Create an instance of MetricsCalculator
metrics_calculator = MetricsCalculator(references, hypothesis)
metrics_calculator.compute_bleu()
metrics_calculator.compute_rouge_l()
metrics_calculator.compute_cider()
metrics_calculator.compute_meteor()

scores = metrics_calculator.scores
show_metrics(scores)
# Out:
# {'testlen': 11979, 'reflen': 10972, 'guess': [11979, 10887, 9795, 8703], 'correct': [5466, 1269, 489, 167]}
# ratio: 1.0917790740064626
# ╒══════════╤═══════════╕
# │ Metric   │     Value │
# ╞══════════╪═══════════╡
# │ BLEU-1   │ 45.63     │
# ├──────────┼───────────┤
# │ BLEU-2   │ 23.06     │
# ├──────────┼───────────┤
# │ BLEU-3   │ 13.85     │
# ├──────────┼───────────┤
# │ BLEU-4   │  8.45     │
# ├──────────┼───────────┤
# │ ROUGE-L  │ 37.2      │
# ├──────────┼───────────┤
# │ CIDEr    │  0.205775 │
# ├──────────┼───────────┤
# │ METEOR   │ 15.76     │
# ╘══════════╧═══════════╛
