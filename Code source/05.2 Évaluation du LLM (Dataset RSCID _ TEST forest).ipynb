# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path_json = "/content/drive/MyDrive/Classroom/MSV/dataset RSICD/dataset_rsicd.json"
path_img_folder = "/content/drive/MyDrive/Classroom/MSV/dataset RSICD/images"

import json

# Charger le fichier JSON
with open(path_json, 'r') as file:
    data = json.load(file)

# Création du dataset
dataset_map = {}
for item in data["images"]:
    filename = item['filename']
    captions = [sent['raw'] for sent in item['sentences']]
    dataset_map[filename] = captions

# %%
# Afficher un exemple
ex = "park_90.jpg"
if ex in dataset_map:
    print("Image path :", ex)
    print("Labels :")
    print(dataset_map[ex])
# Out:
# Image path : park_90.jpg
# Labels :
# ['there are all sorts of play equipment in the park .', 'park is located in a hub, surrounded by the road .', 'some buildings and many green trees are in a park with several ponds .', 'some buildings and many green trees are in a park with several ponds .', 'there are all sorts of play equipment in the park .']

# %%
import pandas as pd
import json

# Charger le fichier CSV
df = pd.read_csv('/content/drive/MyDrive/Classroom/MSV/predictions_2.csv')

# Filtrer les lignes où la colonne 'filename' conient le mot 'forest'
filtered_df = df[df['filename'].str.contains('park_', case=False, na=False)]

# Créer les dictionnaires avec les références
hypothesis = {f"ref_{i+1}": [row['pred_output']] for i, row in filtered_df.iterrows()}
references = {f"ref_{i+1}": dataset_map[row['filename']][:5] for i, row in filtered_df.iterrows()}

# Afficher les dictionnaires
print("Hypothesis:", hypothesis)
print(len(hypothesis))
print("References:", references)
print(len(references))
# Out:
# Hypothesis: {'ref_448': ['some buildings and green trees are in a piece of farmland in a park .'], 'ref_449': ['many buildings and some green trees are in a park .'], 'ref_450': ['a small pond is surrounded by many green trees in a park .'], 'ref_451': ['many green trees and buildings are in a park .'], 'ref_452': ['many green trees and buildings are in a park .'], 'ref_453': ['many buildings and green trees are in a parking lot .'], 'ref_454': ['the two sides of a river are green meadows with a few trees .'], 'ref_455': ['many green trees and buildings are in a park .'], 'ref_456': ['a piece of water is surrounded by green trees and several buildings .'], 'ref_457': ['many green trees and some buildings are in a piece of farmland .'], 'ref_458': ['a long river is near a piece of green forest .'], 'ref_459': ['the parking lot is full of cars .'], 'ref_460': ['the road is curved and surrounded by a green field .'], 'ref_461': ['some green trees are in a piece of farmland .'], 'ref_462': ['the green trees are in the dense forest .'], 'ref_463': ['the white building is in a park .'], 'ref_464': ['many green trees and a pond are in a park .'], 'ref_465': ['the red building is a school with two playgrounds in front of it .'], 'ref_466': ['many green trees and buildings are in a park .'], 'ref_467': ['a large pond is near a river and many green trees in a park .'], 'ref_468': ['some buildings are in a piece of green park .'], 'ref_469': ['the two buildings are near a pool with dark water in a park .'], 'ref_470': ['some green trees are in a piece of green land in a park with a pond .'], 'ref_471': ['many green trees are in a piece of meadow .'], 'ref_472': ['a green meadow is in a piece of farmland with game.'], 'ref_473': ['some buildings and many green trees are in a park with several ponds .'], 'ref_474': ['some buildings and green trees are in a piece of farmland .'], 'ref_475': ['the green meadow is in a large piece of land .'], 'ref_476': ['many green trees are near a river in a park .'], 'ref_477': ['a large piece of land is near a river in a park .'], 'ref_478': ['many green trees are in a piece of land in a park .'], 'ref_479': ['the two sides of the river are surrounded by green trees and a few buildings in a park .'], 'ref_480': ['the two sides of the road are covered with green trees in a park .'], 'ref_481': ['a piece of green lawn is in a piece of yellow sand .'], 'ref_482': ['some very large buildings are in a park green area .']}
# 35
# References: {'ref_448': ['there are two lakes in the park .', 'the park is covered with trees around .', 'many buildings are near a park with many green trees and two ponds .', 'many buildings are near a park with many green trees and two ponds .', 'there are two lakes in the park .'], 'ref_449': ['the park has a lot of running car on the road around .', 'there are several lake in the park .', 'beside the road there is a big par .', 'the park has a lot of green plants and the way for people to walk .', 'many green trees and several ponds are in a park .'], 'ref_450': ["the park's construction is very complete .", 'beside the park filled with green trees .', 'many green trees and game facilities are in a park .', 'many green trees and game facilities are in a park .', "the park's construction is very complete ."], 'ref_451': ['around the park on the road covered with green trees .', 'there are a lot of cars in the park .', 'many green trees and buildings are in a park .', 'many green trees and buildings are in a park .', 'around the park on the road covered with green trees .'], 'ref_452': ['the park has a meeting place for people rest and recreation .', 'beside the park with a lot of trees .', 'many green trees and several ponds are in a park .', 'many green trees and several ponds are in a park .', 'the park has a meeting place for people rest and recreation .'], 'ref_453': ['a lot of car parked in the park .', 'a piece of green trees in the park .', 'many green trees and a pond are in a park near a parking lot .', 'many green trees and a pond are in a park near a parking lot .', 'a lot of car parked in the park .'], 'ref_454': ['distributed the rectangular shape on the ground of the park .', 'park inside a lot of trees .', 'some buildings are around a park with many green trees and a pond .', 'some buildings are around a park with many green trees and a pond .', 'distributed the rectangular shape on the ground of the park .'], 'ref_455': ['there are two umbrella buildings in the park .', 'surrounded by a row of trees in the park .', 'many green trees are in a park near a parking lot and beach .', 'many green trees are in a park near a parking lot and beach .', 'there are two umbrella buildings in the park .'], 'ref_456': ['distribution of the interlaced walkway in the park .', 'on the ground and a bright green lake .', 'many buildings and a river are around a park with many green trees .', 'many buildings and a river are around a park with many green trees .', 'distribution of the interlaced walkway in the park .'], 'ref_457': ['several buildings and green meadows are in a park near roads .', 'several buildings and green meadows are in a park near roads .', 'several buildings and green meadows are in a park near roads .', 'several buildings and green meadows are in a park near roads .', 'several buildings and green meadows are in a park near roads .'], 'ref_458': ['the park covers an area of large .', 'there are many car park outside .', 'some buildings and green trees are in a park .', 'some buildings and green trees are in a park .', 'the park covers an area of large .'], 'ref_459': ['it is a park with dark green water in the middle .', 'the park is surrounded by green plants and grey road .', 'many buildings are around a park with many green trees and a pond .', 'many buildings are around a park with many green trees and a pond .', 'it is a park with dark green water in the middle .'], 'ref_460': ['the path in the park very much .', 'park on the ground are covered with grass .', 'many green trees and several ponds are in a park .', 'many green trees and several ponds are in a park .', 'the path in the park very much .'], 'ref_461': ["the park's facilities are complete .", 'there are many cars on the road near the park .', 'many green trees and a pond are in a park .', 'many green trees and a pond are in a park .', "the park's facilities are complete ."], 'ref_462': ['the lake has a beach .', 'park green vegetation forms . ...
# 35

# %%
# !pip install tabulate
# !pip install pycocoevalcap
# Out:
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (0.9.0)
# Requirement already satisfied: pycocoevalcap in /usr/local/lib/python3.10/dist-packages (1.2)
# Requirement already satisfied: pycocotools>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from pycocoevalcap) (2.0.7)
# Requirement already satisfied: matplotlib>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from pycocotools>=2.0.2->pycocoevalcap) (3.7.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from pycocotools>=2.0.2->pycocoevalcap) (1.25.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap) (24.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap) (1.16.0)

# %%
import pandas as pd
import re
from pycocoevalcap.bleu.bleu import Bleu
from pycocoevalcap.rouge.rouge import Rouge
from pycocoevalcap.cider.cider import Cider
from pycocoevalcap.meteor.meteor import Meteor
from tabulate import tabulate

def show_metrics(metrics):
    table_data = []
    for metric, value in metrics.items():
        table_data.append([metric, value])
    headers = ['Metric', 'Value']
    print(tabulate(table_data, headers=headers, tablefmt='fancy_grid'))

class MetricsCalculator:
    def __init__(self, references, hypotheses, n_gram=4):
        self.references = references
        self.hypotheses = hypotheses
        self.n_gram = n_gram
        self.bleu = Bleu(self.n_gram)
        self.rouge = Rouge()
        self.cider = Cider()
        self.meteor = Meteor()
        self.scores = {}

    def compute_bleu(self):
        bleu_scores = self.bleu.compute_score(self.references, self.hypotheses)
        for i in range(self.n_gram):
            self.scores[f"BLEU-{i+1}"] = f"{bleu_scores[0][i] * 100:.2f}"  # Convert to percentage

    def compute_rouge_l(self):
        rouge_scores, _ = self.rouge.compute_score(self.references, self.hypotheses)
        self.scores["ROUGE-L"] = f"{rouge_scores * 100:.2f}"

    def compute_cider(self):
        scores, _ = self.cider.compute_score(self.references, self.hypotheses)
        self.scores["CIDEr"] = scores

    def compute_meteor(self):
        scores, _ = self.meteor.compute_score(self.references, self.hypotheses)
        self.scores["METEOR"] = f"{scores * 100:.2f}"

# Create an instance of MetricsCalculator
metrics_calculator = MetricsCalculator(references, hypothesis)
metrics_calculator.compute_bleu()
metrics_calculator.compute_rouge_l()
metrics_calculator.compute_cider()
metrics_calculator.compute_meteor()

scores = metrics_calculator.scores
show_metrics(scores)
# Out:
# {'testlen': 421, 'reflen': 394, 'guess': [421, 386, 351, 316], 'correct': [271, 139, 83, 47]}
# ratio: 1.068527918779014
# ╒══════════╤═══════════╕
# │ Metric   │     Value │
# ╞══════════╪═══════════╡
# │ BLEU-1   │ 64.37     │
# ├──────────┼───────────┤
# │ BLEU-2   │ 48.15     │
# ├──────────┼───────────┤
# │ BLEU-3   │ 37.99     │
# ├──────────┼───────────┤
# │ BLEU-4   │ 30.05     │
# ├──────────┼───────────┤
# │ ROUGE-L  │ 53.95     │
# ├──────────┼───────────┤
# │ CIDEr    │  0.539267 │
# ├──────────┼───────────┤
# │ METEOR   │ 28.44     │
# ╘══════════╧═══════════╛
